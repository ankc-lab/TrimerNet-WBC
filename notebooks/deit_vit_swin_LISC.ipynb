# %%
import torch
import gc

gc.collect()

if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import cv2
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import DeiTForImageClassification, DeiTConfig, ViTForImageClassification, ViTConfig, SwinForImageClassification, SwinConfig
from sklearn.preprocessing import label_binarize
import copy
import time
import random

# %%
# Set device for PyTorch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Set seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed()
# Out:
# Device: cuda

# %%
# Data paths
train_path = 'path/to/LISC/train'
test_path = 'path/to/LISC/test'
validation_path = 'path/to/LISC/validation'

# Class labels
class_labels = {
    "Basophil": 0,
    "Eosinophil": 1,
    "Lymphocyte": 2,
    "Monocyte": 3,
    "Neutrophil": 4,
}

# %%
# Image processing function
def process_image(image):
    """
    Process an image with CLAHE histogram equalization
    
    Parameters:
    - image: Input RGB image
    
    Returns:
    - Processed image tensor
    """
    # CLAHE histogram equalization (applied only to V channel)
    hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    h, s, v = cv2.split(hsv)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    cl = clahe.apply(v)
    himg = cv2.merge((h, s, cl))
    processed_img = cv2.cvtColor(himg, cv2.COLOR_HSV2RGB)

    # Resize and normalize
    resized = cv2.resize(processed_img, (384, 384), interpolation=cv2.INTER_AREA)
    normalized = resized / 255.0
    
    return normalized

# %%
class FilePathDataset(Dataset):
    def __init__(self, data_path):
        self.file_paths = []
        self.labels = []
        
        # Walk through data directories and collect file paths and labels
        for folder_name in os.listdir(data_path):
            folder_path = os.path.join(data_path, folder_name)
            if os.path.isdir(folder_path):
                # Check class label
                label = class_labels.get(folder_name)
                if label is not None:
                    # Collect all jpg files in this folder
                    for file_name in os.listdir(folder_path):
                        if file_name.endswith(".jpg"):
                            file_path = os.path.join(folder_path, file_name)
                            self.file_paths.append(file_path)
                            self.labels.append(label)
    
    def __len__(self):
        return len(self.file_paths)
    
    def __getitem__(self, idx):
        img_path = self.file_paths[idx]
        label = self.labels[idx]
        
        # Load image
        try:
            image = cv2.imread(img_path)
            if image is None:
                raise ValueError(f"Image could not be loaded: {img_path}")
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Use process_image function
            processed_img = process_image(image)
            
            # Convert to tensor
            processed_img = torch.tensor(processed_img, dtype=torch.float32).permute(2, 0, 1)  # (3, 384, 384)
            return processed_img, torch.tensor(label, dtype=torch.long)
            
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a dummy image in case of error
            dummy_img = torch.zeros((3, 384, 384), dtype=torch.float32)
            return dummy_img, torch.tensor(label, dtype=torch.long)

# %%
# Create DataLoaders with optimized settings
def create_data_loaders(batch_size=32, num_workers=0):
    """
    Create memory-efficient data loaders
    
    Parameters:
    - batch_size: Batch size for training
    - num_workers: Number of workers for parallel data loading
    """
    train_dataset = FilePathDataset(train_path)
    val_dataset = FilePathDataset(validation_path)
    test_dataset = FilePathDataset(test_path)
    
    print(f"Training dataset: {len(train_dataset)} samples")
    print(f"Validation dataset: {len(val_dataset)} samples")
    print(f"Test dataset: {len(test_dataset)} samples")
    
    # Check class distribution
    train_labels = np.array(train_dataset.labels)
    val_labels = np.array(val_dataset.labels)
    test_labels = np.array(test_dataset.labels)
    
    print("\nTraining data class distribution:")
    print(pd.Series(train_labels).value_counts().sort_index())
    
    print("\nValidation data class distribution:")
    print(pd.Series(val_labels).value_counts().sort_index())
    
    print("\nTest data class distribution:")
    print(pd.Series(test_labels).value_counts().sort_index())
    
    train_loader = DataLoader(
        train_dataset, 
        batch_size=batch_size, 
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True  # For faster memory transfer with GPU
    )
    
    val_loader = DataLoader(
        val_dataset, 
        batch_size=batch_size, 
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )
    
    test_loader = DataLoader(
        test_dataset, 
        batch_size=batch_size, 
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )
    
    return train_loader, val_loader, test_loader, test_dataset

# %%
# Custom model class with Batch Normalization for DeiT
class EnhancedDeiTModel(nn.Module):
    def __init__(self, pretrained_model, num_classes=5):
        super(EnhancedDeiTModel, self).__init__()
        self.backbone = pretrained_model
        
        # Add batch normalization to stabilize training
        self.batch_norm = nn.BatchNorm1d(self.backbone.config.hidden_size)
        
        # Replace the classification head
        self.classifier = nn.Sequential(
            nn.Linear(self.backbone.config.hidden_size, 512),
            nn.BatchNorm1d(512),
            nn.GELU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
        
        # Initialize the classifier weights
        for module in self.classifier.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
    
    def forward(self, x):
        # Extract features from the backbone
        outputs = self.backbone(x, output_hidden_states=True)
        
        # Get the [CLS] token representation
        cls_token = outputs.hidden_states[-1][:, 0]
        
        # Apply batch normalization
        normalized = self.batch_norm(cls_token)
        
        # Forward through classifier
        logits = self.classifier(normalized)
        
        return logits

# %%
# Custom model class with Batch Normalization for ViT
class EnhancedViTModel(nn.Module):
    def __init__(self, pretrained_model, num_classes=5):
        super(EnhancedViTModel, self).__init__()
        self.backbone = pretrained_model
        
        # Add batch normalization to stabilize training
        self.batch_norm = nn.BatchNorm1d(self.backbone.config.hidden_size)
        
        # Replace the classification head
        self.classifier = nn.Sequential(
            nn.Linear(self.backbone.config.hidden_size, 512),
            nn.BatchNorm1d(512),
            nn.GELU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
        
        # Initialize the classifier weights
        for module in self.classifier.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
    
    def forward(self, x):
        # Extract features from the backbone
        outputs = self.backbone(x, output_hidden_states=True)
        
        # Get the [CLS] token representation
        cls_token = outputs.hidden_states[-1][:, 0]
        
        # Apply batch normalization
        normalized = self.batch_norm(cls_token)
        
        # Forward through classifier
        logits = self.classifier(normalized)
        
        return logits

# %%
# Custom model class with Batch Normalization for Swin Transformer
class EnhancedSwinModel(nn.Module):
    def __init__(self, pretrained_model, num_classes=5):
        super(EnhancedSwinModel, self).__init__()
        self.backbone = pretrained_model
        
        # Add batch normalization to stabilize training
        self.batch_norm = nn.BatchNorm1d(self.backbone.config.hidden_size)
        
        # Replace the classification head with a more complex one
        self.classifier = nn.Sequential(
            nn.Linear(self.backbone.config.hidden_size, 768),
            nn.BatchNorm1d(768),
            nn.GELU(),
            nn.Dropout(0.5),
            nn.Linear(768, num_classes)

        )
        
        # Initialize the classifier weights
        for module in self.classifier.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
    
    def forward(self, x):
            # Extract features from the backbone
            outputs = self.backbone(x, output_hidden_states=True)
            
            # Get the correct output for Swin
            last_hidden_state = outputs.hidden_states[-1]
            # Apply global average pooling
            pooled_output = torch.mean(last_hidden_state, dim=1)
            
            # Apply batch normalization
            normalized = self.batch_norm(pooled_output)
            
            # Forward through classifier
            logits = self.classifier(normalized)
            
            return logits

# %%
# Create class-weighted loss function
def get_weighted_loss():
    # Class counts from training set
    counts = np.array([285, 302, 301, 288, 286])
    weights = 1.0 / (counts / np.sum(counts))
    class_weights = torch.FloatTensor(weights).to(device)
    return nn.CrossEntropyLoss(weight=class_weights)

# %%
# Create ensemble models
def create_ensemble_models():
    # DeiT model
    deit_config = DeiTConfig.from_pretrained('facebook/deit-base-distilled-patch16-384', num_labels=5)
    deit_base = DeiTForImageClassification.from_pretrained(
        'facebook/deit-base-distilled-patch16-384', 
        config=deit_config,
        ignore_mismatched_sizes=True
    )
    deit_model = EnhancedDeiTModel(deit_base)
    
    # ViT model
    vit_config = ViTConfig.from_pretrained('google/vit-base-patch16-384', num_labels=5)
    vit_base = ViTForImageClassification.from_pretrained(
        'google/vit-base-patch16-384', 
        config=vit_config,
        ignore_mismatched_sizes=True
    )
    vit_model = EnhancedViTModel(vit_base)

    # Swin Transformer model
    swin_config = SwinConfig.from_pretrained('microsoft/swin-base-patch4-window12-384', num_labels=5)
    swin_base = SwinForImageClassification.from_pretrained(
        'microsoft/swin-base-patch4-window12-384', 
        config=swin_config,
        ignore_mismatched_sizes=True
    )
    swin_model = EnhancedSwinModel(swin_base)
    
    return [deit_model.to(device), vit_model.to(device), swin_model.to(device)]

# %%
# Model evaluation function
def evaluate_model(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            
            # Handle Hugging Face model outputs
            if hasattr(outputs, 'logits'):
                logits = outputs.logits
            else:
                logits = outputs
                
            loss = criterion(logits, labels)
            running_loss += loss.item()

            _, preds = torch.max(logits, 1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = running_loss / len(val_loader)
    accuracy = correct_preds / total_preds
    return val_loss, accuracy, all_preds, all_labels

# %%
# Print function for trainable parameters
def print_trainable_params(model):
    """Print statistics about trainable parameters"""
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Trainable parameters: {trainable_params:,} / {total_params:,} ({trainable_params/total_params:.2%})")

# %%
# Improved progressive unfreezing function
def unfreeze_layers_progressively(model, epoch, total_epochs):
    progress = epoch / total_epochs
    
    # Initial epoch - Only train classifier layers
    if epoch == 0:
        # Freeze all parameters
        for param in model.parameters():
            param.requires_grad = False
            
        # Unfreeze only the classifier
        if hasattr(model, 'classifier'):
            for param in model.classifier.parameters():
                param.requires_grad = True
        # For Hugging Face models
        elif hasattr(model, 'classifier') and hasattr(model.classifier, 'parameters'):
            for param in model.classifier.parameters():
                param.requires_grad = True
        # For alternative architectures
        elif hasattr(model, 'head') and hasattr(model.head, 'parameters'):
            for param in model.head.parameters():
                param.requires_grad = True
        
        print_trainable_params(model)
        return
    
    # More gradual unfreezing (4 stages)
    elif progress >= 0.25 and progress < 0.5:
        # Unfreeze last 10% of layers
        backbone_params = []
        if hasattr(model, 'backbone'):
            backbone_params = list(model.backbone.parameters())
        else:
            # If model is directly a backbone
            backbone_params = list(model.parameters())
        
        # Calculate total parameter count
        total_params = len(backbone_params)
        
        # Unfreeze the last 10%
        unfreeze_idx = int(total_params * 0.9)
        for i, param in enumerate(reversed(backbone_params)):
            if i < total_params - unfreeze_idx:
                param.requires_grad = True
    
    elif progress >= 0.5 and progress < 0.75:
        # Unfreeze last 25% of layers
        backbone_params = []
        if hasattr(model, 'backbone'):
            backbone_params = list(model.backbone.parameters())
        else:
            backbone_params = list(model.parameters())
        
        total_params = len(backbone_params)
        
        # Unfreeze the last 25%
        unfreeze_idx = int(total_params * 0.75)
        for i, param in enumerate(reversed(backbone_params)):
            if i < total_params - unfreeze_idx:
                param.requires_grad = True
    
    elif progress >= 0.75:
        # Unfreeze last 50% of layers
        backbone_params = []
        if hasattr(model, 'backbone'):
            backbone_params = list(model.backbone.parameters())
        else:
            backbone_params = list(model.parameters())
        
        total_params = len(backbone_params)
        
        # Unfreeze the last 50%
        unfreeze_idx = int(total_params * 0.5)
        for i, param in enumerate(reversed(backbone_params)):
            if i < total_params - unfreeze_idx:
                param.requires_grad = True
                
    print_trainable_params(model)

# %%
# Training function with progressive unfreezing
def train_model_with_progressive_unfreezing(model, train_loader, val_loader, epochs, lr, patience, save_path):
    """Training with progressive unfreezing and ReduceLROnPlateau learning rate scheduling"""
    # Freeze all parameters initially
    for param in model.parameters():
        param.requires_grad = False
        
    # Unfreeze classifier
    for param in model.classifier.parameters():
        param.requires_grad = True
    
    # Define optimizer with weight decay
    optimizer = optim.AdamW(
        filter(lambda p: p.requires_grad, model.parameters()), 
        lr=lr, 
        weight_decay=0.001  # Reduced from 0.01
    )
    
    # Use ReduceLROnPlateau scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',          # Try to minimize validation loss
        factor=0.5,          # Multiply learning rate by 0.2 when reducing
        patience=2,          # Wait 3 epochs before reducing
        min_lr=lr/2000       # Minimum learning rate
    )
    
    criterion = get_weighted_loss()

    best_val_loss = float('inf')
    best_val_accuracy = 0.0
    epochs_without_improvement = 0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    learning_rates = []

    for epoch in range(epochs):
        start_time = time.time()
        
        # Apply progressive unfreezing
        unfreeze_layers_progressively(model, epoch, epochs)

        if epoch == 0:
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.5,
            patience=2,
            min_lr=lr/2000
            )
        
        # Update optimizer to include newly unfrozen parameters
        if epoch > 0:
            # Get current learning rate
            last_lr = optimizer.param_groups[0]['lr']
            
            # Update optimizer
            optimizer = optim.AdamW(
                filter(lambda p: p.requires_grad, model.parameters()), 
                lr=last_lr,  # Use current learning rate
                weight_decay=0.001
            )
            
            scheduler.optimizer = optimizer
        
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            
            # Handle Hugging Face model outputs
            if hasattr(outputs, 'logits'):
                logits = outputs.logits
            else:
                logits = outputs
                
            loss = criterion(logits, labels)
            loss.backward()
            
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()

            running_loss += loss.item()
            _, preds = torch.max(logits, 1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = correct_preds / total_preds
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        # Validation
        val_loss, val_accuracy, _, _ = evaluate_model(model, val_loader, criterion)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)
        
        # Step scheduler based on validation loss
        scheduler.step(val_loss)

        # Save current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)

        end_time = time.time()
        epoch_duration = end_time - start_time
        estimated_remaining_time = epoch_duration * (epochs - epoch - 1)
        estimated_remaining_minutes = estimated_remaining_time / 60

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Training Loss: {epoch_loss:.4f}, Train accuracy: {epoch_accuracy:.4f}")
        print(f"Validation Loss: {val_loss:.4f}, Validation accuracy: {val_accuracy:.4f}")
        print(f"Epoch {epoch+1} completed in {epoch_duration:.2f} seconds")
        print(f"Estimated time remaining: {estimated_remaining_minutes:.2f} minutes")
        print(f"Epoch {epoch+1}, Learning Rate: {current_lr:.8f}")

        # Save the best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), save_path)
            print(f"Model improved, saved to {save_path}!")
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        # Early stopping
        if epochs_without_improvement >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
                
        print("Performing memory cleanup...")
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        print(f"Memory cleaned after epoch {epoch+1}")

    return train_losses, val_losses, train_accuracies, val_accuracies, learning_rates

# %%
# Calculate weights for ensemble models based on validation performance
def calculate_ensemble_weights(models, val_loader):
    individual_accuracies = []
    criterion = get_weighted_loss()
    
    for model in models:
        _, val_accuracy, _, _ = evaluate_model(model, val_loader, criterion)
        individual_accuracies.append(val_accuracy)
    
    # Normalize accuracies to get weights
    total_accuracy = sum(individual_accuracies)
    weights = [acc/total_accuracy for acc in individual_accuracies]
    
    print("Ensemble model weights based on validation accuracy:")
    for i, weight in enumerate(weights):
        print(f"Model {i+1}: {weight:.4f}")
        
    return weights

# %%
# Ensemble prediction function
def ensemble_predict(models, test_loader, weights=None):
    # Normalize weights
    if weights is None:
        weights = np.ones(len(models)) / len(models)
    else:
        weights = np.array(weights) / np.sum(weights)
    
    all_probabilities = []
    all_labels = []
    
    # For each example, get predictions from each model
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            batch_probs = np.zeros((inputs.size(0), len(class_labels)))
            
            # Add weighted contribution from each model
            for i, model in enumerate(models):
                model.eval()
                outputs = model(inputs)
                
                if hasattr(outputs, 'logits'):
                    logits = outputs.logits
                else:
                    logits = outputs
                
                probs = torch.softmax(logits, dim=1).cpu().numpy()
                batch_probs += weights[i] * probs
            
            all_probabilities.append(batch_probs)
            all_labels.extend(labels.cpu().numpy())
    
    # Combine and get predictions
    all_probabilities = np.vstack(all_probabilities)
    predictions = np.argmax(all_probabilities, axis=1)
    
    return predictions, all_probabilities, np.array(all_labels)

# %%
# Test ensemble model
def test_ensemble(models, test_loader, test_dataset, model_weights=None):
    # Get ensemble predictions with model weighting
    test_labels = np.array(test_dataset.labels)
    predictions, probabilities, _ = ensemble_predict(models, test_loader, weights=model_weights)
    
    # Calculate accuracy
    accuracy = np.mean(predictions == test_labels)
    print(f"Ensemble Test Accuracy: {accuracy:.4f}")
    
    # Create confusion matrix
    cm = confusion_matrix(test_labels, predictions)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=list(class_labels.keys()), 
                yticklabels=list(class_labels.keys()))
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Ensemble Model Confusion Matrix')
    plt.savefig('ensemble_confusion_matrix.png', dpi=300)
    plt.show()
    
    # Classification report
    print("\nClassification Report:")
    print(classification_report(test_labels, predictions, 
                               target_names=list(class_labels.keys()), 
                               digits=4))
    
    # ROC curve
    plt.figure(figsize=(10, 8))
    test_labels_bin = label_binarize(test_labels, classes=list(range(len(class_labels))))
    
    for i in range(len(class_labels)):
        fpr, tpr, _ = roc_curve(test_labels_bin[:, i], probabilities[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{list(class_labels.keys())[i]} (AUC = {roc_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Ensemble Model ROC Curve')
    plt.legend(loc="lower right")
    plt.savefig('ensemble_roc_curve.png', dpi=300)
    plt.show()
    
    return accuracy, predictions, probabilities

# %%
def main():
    # Create data loaders
    train_loader, val_loader, test_loader, test_dataset = create_data_loaders(
        batch_size=32,  # Increased batch size
        num_workers=0   # Adjust based on system cores
    )

    # Create ensemble models
    models = create_ensemble_models()
    
    # Training configuration
    config = {
        "epochs": 30,         
        "learning_rate": 5e-5, 
        "patience": 5          
    }
    
    # Train each model in the ensemble
    trained_models = []
    model_names = ["DeiT", "ViT", "Swin"]
    
    for i, model in enumerate(models):
        print(f"\nTraining {model_names[i]} model...")
        
        # Define model save path
        model_save_path = f'{model_names[i]}_best_model.pth'
        
        # Train with progressive unfreezing
        train_losses, val_losses, train_accuracies, val_accuracies, learning_rates = train_model_with_progressive_unfreezing(
            model, 
            train_loader, 
            val_loader, 
            config["epochs"], 
            config["learning_rate"], 
            config["patience"],
            model_save_path
        )
        
        # Plot training metrics
        fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
        
        # Loss plot
        ax1.plot(train_losses, label='Training Loss', marker='o')
        ax1.plot(val_losses, label='Validation Loss', marker='o')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Loss')
        ax1.set_title(f'{model_names[i]} - Training and Validation Loss')
        ax1.legend()
        ax1.grid()
        
        # Accuracy plot
        ax2.plot(train_accuracies, label='Training Accuracy', marker='o')
        ax2.plot(val_accuracies, label='Validation Accuracy', marker='o')
        ax2.set_xlabel('Epoch')
        ax2.set_ylabel('Accuracy')
        ax2.set_title(f'{model_names[i]} - Training and Validation Accuracy')
        ax2.legend()
        ax2.grid()
        
        plt.savefig(f'{model_names[i]}_training_validation_metrics.png', dpi=300)
        plt.show()
        
        # Learning rate plot
        plt.figure(figsize=(10, 6))
        plt.plot(learning_rates, label='Learning Rate', marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title(f'{model_names[i]} - Learning Rate Schedule')
        plt.legend()
        plt.grid()
        plt.yscale('log')
        plt.savefig(f'{model_names[i]}_learning_rate.png', dpi=300)
        plt.show()
        
        # Load the best model weights if the file exists
        if os.path.exists(model_save_path):
            print(f"Loading best model weights from {model_save_path}")
            model.load_state_dict(torch.load(model_save_path))
        else:
            print(f"No saved model found at {model_save_path}, using the current model state")
        
        trained_models.append(model)

        # Memory cleanup after each model
        print(f"Cleaning up memory after training {model_names[i]}...")
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        print(f"Memory cleanup completed for {model_names[i]}")
        
    
    # Calculate ensemble weights based on validation performance
    model_weights = calculate_ensemble_weights(trained_models, val_loader)
    
    # Test the ensemble model
    print("\nEvaluating ensemble model performance...")
    ensemble_accuracy, ensemble_predictions, ensemble_probabilities = test_ensemble(
        trained_models, 
        test_loader, 
        test_dataset,
        model_weights
    )
    
    # Compare individual model performance with ensemble
    print("\nModel Performance Comparison:")
    print("-" * 50)
    
    individual_accuracies = []
    for i, model in enumerate(trained_models):
        model_name = model_names[i]
        val_loss, val_accuracy, _, _ = evaluate_model(model, test_loader, get_weighted_loss())
        individual_accuracies.append(val_accuracy)
        print(f"{model_name} Test Accuracy: {val_accuracy:.4f}")
    
    print(f"Ensemble Test Accuracy: {ensemble_accuracy:.4f}")
    if individual_accuracies:
        print(f"Improvement over best individual model: {(ensemble_accuracy - max(individual_accuracies)) * 100:.2f}%")
    
    # Save the ensemble model
    ensemble_models = {
        "models": [model.state_dict() for model in trained_models],
        "model_names": model_names,
        "class_labels": class_labels,
        "model_weights": model_weights
    }
    torch.save(ensemble_models, "blood_cell_classification_ensemble.pth")
    print("Ensemble model saved successfully!")

if __name__ == "__main__":
    main()
# Out:
# Training dataset: 1462 samples
# Validation dataset: 415 samples
# Test dataset: 206 samples
#
# Training data class distribution:
# 0    285
# 1    302
# 2    301
# 3    288
# 4    286
# Name: count, dtype: int64
#
# Validation data class distribution:
# 0    81
# 1    86
# 2    85
# 3    82
# 4    81
# Name: count, dtype: int64
#
# Test data class distribution:
# 0    40
# 1    43
# 2    42
# 3    41
# 4    40
# Name: count, dtype: int64
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-384 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-384 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([5]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([5, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of SwinForImageClassification were not initialized from the model checkpoint at microsoft/swin-base-patch4-window12-384 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 1024]) in the checkpoint and torch.Size([5, 1024]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([5]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training DeiT model...
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 1/30
# Training Loss: 10.9740, Train accuracy: 0.3297
# Validation Loss: 3.6628, Validation accuracy: 0.5566
# Epoch 1 completed in 20.41 seconds
# Estimated time remaining: 9.87 minutes
# Epoch 1, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 1
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 2/30
# Training Loss: 6.6559, Train accuracy: 0.4966
# Validation Loss: 2.2517, Validation accuracy: 0.7205
# Epoch 2 completed in 20.36 seconds
# Estimated time remaining: 9.50 minutes
# Epoch 2, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 2
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 3/30
# Training Loss: 4.5044, Train accuracy: 0.6122
# Validation Loss: 1.5213, Validation accuracy: 0.8024
# Epoch 3 completed in 20.34 seconds
# Estimated time remaining: 9.15 minutes
# Epoch 3, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 3
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 4/30
# Training Loss: 3.6618, Train accuracy: 0.6833
# Validation Loss: 1.2146, Validation accuracy: 0.8313
# Epoch 4 completed in 20.45 seconds
# Estimated time remaining: 8.86 minutes
# Epoch 4, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 4
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 5/30
# Training Loss: 2.3974, Train accuracy: 0.7428
# Validation Loss: 0.8776, Validation accuracy: 0.8627
# Epoch 5 completed in 20.50 seconds
# Estimated time remaining: 8.54 minutes
# Epoch 5, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 5
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 6/30
# Training Loss: 2.3978, Train accuracy: 0.7668
# Validation Loss: 0.7249, Validation accuracy: 0.8892
# Epoch 6 completed in 20.44 seconds
# Estimated time remaining: 8.18 minutes
# Epoch 6, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 6
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 7/30
# Training Loss: 1.8874, Train accuracy: 0.8140
# Validation Loss: 0.5894, Validation accuracy: 0.9133
# Epoch 7 completed in 20.41 seconds
# Estimated time remaining: 7.82 minutes
# Epoch 7, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 7
# Trainable parameters: 397,317 / 86,494,730 (0.46%)
# Epoch 8/30
# Training Loss: 1.8512, Train accuracy: 0.8174
# Validation Loss: 0.4847, Validation accuracy: 0.9205
# Epoch 8 completed in 20.43 seconds
# Estimated time remaining: 7.49 minutes
# Epoch 8, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 8
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 9/30
# Training Loss: 1.1138, Train accuracy: 0.8666
# Validation Loss: 0.1227, Validation accuracy: 0.9663
# Epoch 9 completed in 22.97 seconds
# Estimated time remaining: 8.04 minutes
# Epoch 9, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 9
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 10/30
# Training Loss: 0.7062, Train accuracy: 0.9213
# Validation Loss: 0.0880, Validation accuracy: 0.9807
# Epoch 10 completed in 22.79 seconds
# Estimated time remaining: 7.60 minutes
# Epoch 10, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 10
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 11/30
# Training Loss: 0.3487, Train accuracy: 0.9555
# Validation Loss: 0.0726, Validation accuracy: 0.9807
# Epoch 11 completed in 22.88 seconds
# Estimated time remaining: 7.25 minutes
# Epoch 11, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 11
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 12/30
# Training Loss: 0.2267, Train accuracy: 0.9672
# Validation Loss: 0.0434, Validation accuracy: 0.9928
# Epoch 12 completed in 22.80 seconds
# Estimated time remaining: 6.84 minutes
# Epoch 12, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 12
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 13/30
# Training Loss: 0.1520, Train accuracy: 0.9767
# Validation Loss: 0.0496, Validation accuracy: 0.9855
# Epoch 13 completed in 22.85 seconds
# Estimated time remaining: 6.47 minutes
# Epoch 13, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 13
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 14/30
# Training Loss: 0.1059, Train accuracy: 0.9850
# Validation Loss: 0.0240, Validation accuracy: 0.9952
# Epoch 14 completed in 22.99 seconds
# Estimated time remaining: 6.13 minutes
# Epoch 14, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 14
# Trainable parameters: 7,491,338 / 86,494,730 (8.66%)
# Epoch 15/30
# Training Loss: 0.0707, Train accuracy: 0.9863
# Validation Loss: 0.0050, Validation accuracy: 0.9976
# Epoch 15 completed in 22.80 seconds
# Estimated time remaining: 5.70 minutes
# Epoch 15, Learning Rate: 0.00005000
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 15
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 16/30
# Training Loss: 0.1874, Train accuracy: 0.9802
# Validation Loss: 0.0252, Validation accuracy: 0.9928
# Epoch 16 completed in 26.41 seconds
# Estimated time remaining: 6.16 minutes
# Epoch 16, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 16
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 17/30
# Training Loss: 0.0888, Train accuracy: 0.9870
# Validation Loss: 0.0194, Validation accuracy: 0.9976
# Epoch 17 completed in 26.27 seconds
# Estimated time remaining: 5.69 minutes
# Epoch 17, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 17
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 18/30
# Training Loss: 0.0575, Train accuracy: 0.9918
# Validation Loss: 0.0335, Validation accuracy: 0.9928
# Epoch 18 completed in 26.35 seconds
# Estimated time remaining: 5.27 minutes
# Epoch 18, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 18
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 19/30
# Training Loss: 0.0589, Train accuracy: 0.9945
# Validation Loss: 0.0001, Validation accuracy: 1.0000
# Epoch 19 completed in 26.19 seconds
# Estimated time remaining: 4.80 minutes
# Epoch 19, Learning Rate: 0.00002500
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 19
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 20/30
# Training Loss: 0.0154, Train accuracy: 0.9986
# Validation Loss: 0.0193, Validation accuracy: 0.9976
# Epoch 20 completed in 26.37 seconds
# Estimated time remaining: 4.40 minutes
# Epoch 20, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 20
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 21/30
# Training Loss: 0.0542, Train accuracy: 0.9945
# Validation Loss: 0.0064, Validation accuracy: 0.9976
# Epoch 21 completed in 26.32 seconds
# Estimated time remaining: 3.95 minutes
# Epoch 21, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 21
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 22/30
# Training Loss: 0.0191, Train accuracy: 0.9959
# Validation Loss: 0.0001, Validation accuracy: 1.0000
# Epoch 22 completed in 26.37 seconds
# Estimated time remaining: 3.52 minutes
# Epoch 22, Learning Rate: 0.00002500
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 22
# Trainable parameters: 21,076,490 / 86,494,730 (24.37%)
# Epoch 23/30
# Training Loss: 0.0117, Train accuracy: 0.9979
# Validation Loss: 0.0005, Validation accuracy: 1.0000
# Epoch 23 completed in 26.24 seconds
# Estimated time remaining: 3.06 minutes
# Epoch 23, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 23
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 24/30
# Training Loss: 0.0460, Train accuracy: 0.9959
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 24 completed in 32.95 seconds
# Estimated time remaining: 3.29 minutes
# Epoch 24, Learning Rate: 0.00002500
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 24
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 25/30
# Training Loss: 0.0214, Train accuracy: 0.9966
# Validation Loss: 0.0001, Validation accuracy: 1.0000
# Epoch 25 completed in 32.95 seconds
# Estimated time remaining: 2.75 minutes
# Epoch 25, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 25
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 26/30
# Training Loss: 0.0474, Train accuracy: 0.9945
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 26 completed in 32.86 seconds
# Estimated time remaining: 2.19 minutes
# Epoch 26, Learning Rate: 0.00002500
# Model improved, saved to DeiT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 26
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 27/30
# Training Loss: 0.0386, Train accuracy: 0.9952
# Validation Loss: 0.0011, Validation accuracy: 1.0000
# Epoch 27 completed in 32.94 seconds
# Estimated time remaining: 1.65 minutes
# Epoch 27, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 27
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 28/30
# Training Loss: 0.0217, Train accuracy: 0.9979
# Validation Loss: 0.0584, Validation accuracy: 0.9976
# Epoch 28 completed in 33.00 seconds
# Estimated time remaining: 1.10 minutes
# Epoch 28, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 28
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 29/30
# Training Loss: 0.0161, Train accuracy: 0.9979
# Validation Loss: 0.0216, Validation accuracy: 0.9976
# Epoch 29 completed in 32.94 seconds
# Estimated time remaining: 0.55 minutes
# Epoch 29, Learning Rate: 0.00001250
# Performing memory cleanup...
# Memory cleaned after epoch 29
# Trainable parameters: 42,930,698 / 86,494,730 (49.63%)
# Epoch 30/30
# Training Loss: 0.0123, Train accuracy: 0.9979
# Validation Loss: 0.0242, Validation accuracy: 0.9976
# Epoch 30 completed in 32.87 seconds
# Estimated time remaining: 0.00 minutes
# Epoch 30, Learning Rate: 0.00001250
# Performing memory cleanup...
# Memory cleaned after epoch 30
# Loading best model weights from DeiT_best_model.pth
# Cleaning up memory after training DeiT...
# Memory cleanup completed for DeiT
#
# Training ViT model...
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# <temp>\ipykernel\1210711873.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# Epoch 1/30
# Training Loss: 10.3191, Train accuracy: 0.3105
# Validation Loss: 3.9124, Validation accuracy: 0.5181
# Epoch 1 completed in 20.50 seconds
# Estimated time remaining: 9.91 minutes
# Epoch 1, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 1
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 2/30
# Training Loss: 6.3643, Train accuracy: 0.4829
# Validation Loss: 2.1720, Validation accuracy: 0.7036
# Epoch 2 completed in 20.50 seconds
# Estimated time remaining: 9.57 minutes
# Epoch 2, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 2
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 3/30
# Training Loss: 4.4138, Train accuracy: 0.5985
# Validation Loss: 1.2883, Validation accuracy: 0.7976
# Epoch 3 completed in 20.51 seconds
# Estimated time remaining: 9.23 minutes
# Epoch 3, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 3
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 4/30
# Training Loss: 3.2890, Train accuracy: 0.6847
# Validation Loss: 0.8096, Validation accuracy: 0.8602
# Epoch 4 completed in 20.50 seconds
# Estimated time remaining: 8.88 minutes
# Epoch 4, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 4
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 5/30
# Training Loss: 2.7896, Train accuracy: 0.7244
# Validation Loss: 0.6195, Validation accuracy: 0.8795
# Epoch 5 completed in 20.48 seconds
# Estimated time remaining: 8.53 minutes
# Epoch 5, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 5
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 6/30
# Training Loss: 2.0863, Train accuracy: 0.7763
# Validation Loss: 0.4355, Validation accuracy: 0.9229
# Epoch 6 completed in 20.30 seconds
# Estimated time remaining: 8.12 minutes
# Epoch 6, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 6
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 7/30
# Training Loss: 1.9884, Train accuracy: 0.7969
# Validation Loss: 0.3741, Validation accuracy: 0.9373
# Epoch 7 completed in 20.51 seconds
# Estimated time remaining: 7.86 minutes
# Epoch 7, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 7
# Trainable parameters: 397,317 / 86,493,194 (0.46%)
# Epoch 8/30
# Training Loss: 1.7073, Train accuracy: 0.8283
# Validation Loss: 0.3299, Validation accuracy: 0.9518
# Epoch 8 completed in 20.45 seconds
# Estimated time remaining: 7.50 minutes
# Epoch 8, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 8
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 9/30
# Training Loss: 1.1574, Train accuracy: 0.8605
# Validation Loss: 0.2879, Validation accuracy: 0.9663
# Epoch 9 completed in 22.53 seconds
# Estimated time remaining: 7.88 minutes
# Epoch 9, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 9
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 10/30
# Training Loss: 0.7766, Train accuracy: 0.8960
# Validation Loss: 0.2162, Validation accuracy: 0.9831
# Epoch 10 completed in 22.53 seconds
# Estimated time remaining: 7.51 minutes
# Epoch 10, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 10
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 11/30
# Training Loss: 0.6594, Train accuracy: 0.9159
# Validation Loss: 0.1541, Validation accuracy: 0.9783
# Epoch 11 completed in 22.45 seconds
# Estimated time remaining: 7.11 minutes
# Epoch 11, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 11
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 12/30
# Training Loss: 0.4629, Train accuracy: 0.9282
# Validation Loss: 0.1712, Validation accuracy: 0.9831
# Epoch 12 completed in 22.46 seconds
# Estimated time remaining: 6.74 minutes
# Epoch 12, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 12
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 13/30
# Training Loss: 0.3311, Train accuracy: 0.9528
# Validation Loss: 0.1057, Validation accuracy: 0.9855
# Epoch 13 completed in 22.45 seconds
# Estimated time remaining: 6.36 minutes
# Epoch 13, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 13
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 14/30
# Training Loss: 0.2966, Train accuracy: 0.9562
# Validation Loss: 0.1168, Validation accuracy: 0.9855
# Epoch 14 completed in 22.44 seconds
# Estimated time remaining: 5.98 minutes
# Epoch 14, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 14
# Trainable parameters: 7,490,570 / 86,493,194 (8.66%)
# Epoch 15/30
# Training Loss: 0.2664, Train accuracy: 0.9658
# Validation Loss: 0.0993, Validation accuracy: 0.9880
# Epoch 15 completed in 22.36 seconds
# Estimated time remaining: 5.59 minutes
# Epoch 15, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 15
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 16/30
# Training Loss: 0.2631, Train accuracy: 0.9692
# Validation Loss: 0.0677, Validation accuracy: 0.9928
# Epoch 16 completed in 26.31 seconds
# Estimated time remaining: 6.14 minutes
# Epoch 16, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 16
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 17/30
# Training Loss: 0.1016, Train accuracy: 0.9829
# Validation Loss: 0.0387, Validation accuracy: 0.9904
# Epoch 17 completed in 26.33 seconds
# Estimated time remaining: 5.70 minutes
# Epoch 17, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 17
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 18/30
# Training Loss: 0.0926, Train accuracy: 0.9843
# Validation Loss: 0.0464, Validation accuracy: 0.9952
# Epoch 18 completed in 26.38 seconds
# Estimated time remaining: 5.28 minutes
# Epoch 18, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 18
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 19/30
# Training Loss: 0.0803, Train accuracy: 0.9904
# Validation Loss: 0.0235, Validation accuracy: 0.9952
# Epoch 19 completed in 26.40 seconds
# Estimated time remaining: 4.84 minutes
# Epoch 19, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 19
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 20/30
# Training Loss: 0.0883, Train accuracy: 0.9870
# Validation Loss: 0.0246, Validation accuracy: 0.9976
# Epoch 20 completed in 26.34 seconds
# Estimated time remaining: 4.39 minutes
# Epoch 20, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 20
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 21/30
# Training Loss: 0.0371, Train accuracy: 0.9952
# Validation Loss: 0.0109, Validation accuracy: 0.9952
# Epoch 21 completed in 26.33 seconds
# Estimated time remaining: 3.95 minutes
# Epoch 21, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 21
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 22/30
# Training Loss: 0.0261, Train accuracy: 0.9932
# Validation Loss: 0.0001, Validation accuracy: 1.0000
# Epoch 22 completed in 26.39 seconds
# Estimated time remaining: 3.52 minutes
# Epoch 22, Learning Rate: 0.00005000
# Model improved, saved to ViT_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 22
# Trainable parameters: 21,075,722 / 86,493,194 (24.37%)
# Epoch 23/30
# Training Loss: 0.0569, Train accuracy: 0.9932
# Validation Loss: 0.0029, Validation accuracy: 1.0000
# Epoch 23 completed in 26.37 seconds
# Estimated time remaining: 3.08 minutes
# Epoch 23, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 23
# Trainable parameters: 42,929,930 / 86,493,194 (49.63%)
# Epoch 24/30
# Training Loss: 0.0375, Train accuracy: 0.9959
# Validation Loss: 0.0114, Validation accuracy: 0.9976
# Epoch 24 completed in 32.44 seconds
# Estimated time remaining: 3.24 minutes
# Epoch 24, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 24
# Trainable parameters: 42,929,930 / 86,493,194 (49.63%)
# Epoch 25/30
# Training Loss: 0.0700, Train accuracy: 0.9938
# Validation Loss: 0.0677, Validation accuracy: 0.9952
# Epoch 25 completed in 32.49 seconds
# Estimated time remaining: 2.71 minutes
# Epoch 25, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 25
# Trainable parameters: 42,929,930 / 86,493,194 (49.63%)
# Epoch 26/30
# Training Loss: 0.0108, Train accuracy: 0.9979
# Validation Loss: 0.0062, Validation accuracy: 0.9976
# Epoch 26 completed in 32.39 seconds
# Estimated time remaining: 2.16 minutes
# Epoch 26, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 26
# Trainable parameters: 42,929,930 / 86,493,194 (49.63%)
# Epoch 27/30
# Training Loss: 0.0137, Train accuracy: 0.9959
# Validation Loss: 0.0174, Validation accuracy: 0.9976
# Epoch 27 completed in 32.40 seconds
# Estimated time remaining: 1.62 minutes
# Epoch 27, Learning Rate: 0.00002500
# Early stopping at epoch 27
# Loading best model weights from ViT_best_model.pth
# Cleaning up memory after training ViT...
# Memory cleanup completed for ViT
#
# Training Swin model...
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 1/30
# Training Loss: 12.8692, Train accuracy: 0.3290
# Validation Loss: 3.8578, Validation accuracy: 0.5831
# Epoch 1 completed in 26.87 seconds
# Estimated time remaining: 12.99 minutes
# Epoch 1, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 1
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 2/30
# Training Loss: 8.2571, Train accuracy: 0.4904
# Validation Loss: 2.5614, Validation accuracy: 0.7205
# Epoch 2 completed in 26.88 seconds
# Estimated time remaining: 12.55 minutes
# Epoch 2, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 2
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 3/30
# Training Loss: 6.2517, Train accuracy: 0.6088
# Validation Loss: 1.8807, Validation accuracy: 0.7566
# Epoch 3 completed in 26.88 seconds
# Estimated time remaining: 12.10 minutes
# Epoch 3, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 3
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 4/30
# Training Loss: 4.9627, Train accuracy: 0.6587
# Validation Loss: 1.4397, Validation accuracy: 0.8145
# Epoch 4 completed in 26.78 seconds
# Estimated time remaining: 11.61 minutes
# Epoch 4, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 4
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 5/30
# Training Loss: 4.3983, Train accuracy: 0.6819
# Validation Loss: 1.0820, Validation accuracy: 0.8578
# Epoch 5 completed in 26.78 seconds
# Estimated time remaining: 11.16 minutes
# Epoch 5, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 5
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 6/30
# Training Loss: 3.8292, Train accuracy: 0.7298
# Validation Loss: 0.7479, Validation accuracy: 0.8843
# Epoch 6 completed in 26.80 seconds
# Estimated time remaining: 10.72 minutes
# Epoch 6, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 6
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 7/30
# Training Loss: 3.1786, Train accuracy: 0.7469
# Validation Loss: 0.5193, Validation accuracy: 0.9157
# Epoch 7 completed in 26.89 seconds
# Estimated time remaining: 10.31 minutes
# Epoch 7, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 7
# Trainable parameters: 792,581 / 87,678,338 (0.90%)
# Epoch 8/30
# Training Loss: 3.0878, Train accuracy: 0.7647
# Validation Loss: 0.4905, Validation accuracy: 0.9253
# Epoch 8 completed in 26.94 seconds
# Estimated time remaining: 9.88 minutes
# Epoch 8, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 8
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 9/30
# Training Loss: 2.2889, Train accuracy: 0.8269
# Validation Loss: 0.2210, Validation accuracy: 0.9663
# Epoch 9 completed in 28.84 seconds
# Estimated time remaining: 10.10 minutes
# Epoch 9, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 9
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 10/30
# Training Loss: 0.8641, Train accuracy: 0.9207
# Validation Loss: 0.0832, Validation accuracy: 0.9783
# Epoch 10 completed in 28.74 seconds
# Estimated time remaining: 9.58 minutes
# Epoch 10, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 10
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 11/30
# Training Loss: 0.6757, Train accuracy: 0.9439
# Validation Loss: 0.0057, Validation accuracy: 0.9976
# Epoch 11 completed in 28.91 seconds
# Estimated time remaining: 9.15 minutes
# Epoch 11, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 11
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 12/30
# Training Loss: 0.4272, Train accuracy: 0.9672
# Validation Loss: 0.0069, Validation accuracy: 0.9976
# Epoch 12 completed in 28.82 seconds
# Estimated time remaining: 8.65 minutes
# Epoch 12, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 12
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 13/30
# Training Loss: 0.5035, Train accuracy: 0.9672
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 13 completed in 28.85 seconds
# Estimated time remaining: 8.17 minutes
# Epoch 13, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 13
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 14/30
# Training Loss: 0.3619, Train accuracy: 0.9679
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 14 completed in 28.79 seconds
# Estimated time remaining: 7.68 minutes
# Epoch 14, Learning Rate: 0.00005000
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 14
# Trainable parameters: 29,176,394 / 87,678,338 (33.28%)
# Epoch 15/30
# Training Loss: 0.1381, Train accuracy: 0.9822
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 15 completed in 28.85 seconds
# Estimated time remaining: 7.21 minutes
# Epoch 15, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 15
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 16/30
# Training Loss: 0.2325, Train accuracy: 0.9808
# Validation Loss: 0.0087, Validation accuracy: 0.9976
# Epoch 16 completed in 32.61 seconds
# Estimated time remaining: 7.61 minutes
# Epoch 16, Learning Rate: 0.00005000
# Performing memory cleanup...
# Memory cleaned after epoch 16
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 17/30
# Training Loss: 0.2452, Train accuracy: 0.9781
# Validation Loss: 0.0756, Validation accuracy: 0.9904
# Epoch 17 completed in 32.61 seconds
# Estimated time remaining: 7.07 minutes
# Epoch 17, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 17
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 18/30
# Training Loss: 0.0998, Train accuracy: 0.9904
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 18 completed in 32.72 seconds
# Estimated time remaining: 6.54 minutes
# Epoch 18, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 18
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 19/30
# Training Loss: 0.0708, Train accuracy: 0.9938
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 19 completed in 32.76 seconds
# Estimated time remaining: 6.01 minutes
# Epoch 19, Learning Rate: 0.00002500
# Model improved, saved to Swin_best_model.pth!
# Performing memory cleanup...
# Memory cleaned after epoch 19
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 20/30
# Training Loss: 0.0978, Train accuracy: 0.9925
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 20 completed in 32.79 seconds
# Estimated time remaining: 5.47 minutes
# Epoch 20, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 20
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 21/30
# Training Loss: 0.0573, Train accuracy: 0.9966
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 21 completed in 32.82 seconds
# Estimated time remaining: 4.92 minutes
# Epoch 21, Learning Rate: 0.00002500
# Performing memory cleanup...
# Memory cleaned after epoch 21
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 22/30
# Training Loss: 0.0739, Train accuracy: 0.9938
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 22 completed in 32.81 seconds
# Estimated time remaining: 4.37 minutes
# Epoch 22, Learning Rate: 0.00001250
# Performing memory cleanup...
# Memory cleaned after epoch 22
# Trainable parameters: 40,769,674 / 87,678,338 (46.50%)
# Epoch 23/30
# Training Loss: 0.0278, Train accuracy: 0.9973
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 23 completed in 32.79 seconds
# Estimated time remaining: 3.83 minutes
# Epoch 23, Learning Rate: 0.00001250
# Performing memory cleanup...
# Memory cleaned after epoch 23
# Trainable parameters: 60,784,874 / 87,678,338 (69.33%)
# Epoch 24/30
# Training Loss: 0.0327, Train accuracy: 0.9966
# Validation Loss: 0.0000, Validation accuracy: 1.0000
# Epoch 24 completed in 38.95 seconds
# Estimated time remaining: 3.90 minutes
# Epoch 24, Learning Rate: 0.00001250
# Early stopping at epoch 24
# Loading best model weights from Swin_best_model.pth
# Cleaning up memory after training Swin...
# Memory cleanup completed for Swin
# Ensemble model weights based on validation accuracy:
# Model 1: 0.3333
# Model 2: 0.3333
# Model 3: 0.3333
#
# Evaluating ensemble model performance...
# Ensemble Test Accuracy: 0.9951
# Classification Report:
#               precision    recall  f1-score   support
#
#     Basophil     1.0000    1.0000    1.0000        40
#   Eosinophil     1.0000    1.0000    1.0000        43
#   Lymphocyte     1.0000    0.9762    0.9880        42
#     Monocyte     0.9762    1.0000    0.9880        41
#   Neutrophil     1.0000    1.0000    1.0000        40
#
#     accuracy                         0.9951       206
#    macro avg     0.9952    0.9952    0.9952       206
# weighted avg     0.9953    0.9951    0.9951       206
# Model Performance Comparison:
# --------------------------------------------------
# DeiT Test Accuracy: 0.9951
# ViT Test Accuracy: 0.9951
# Swin Test Accuracy: 0.9757
# Ensemble Test Accuracy: 0.9951
# Improvement over best individual model: 0.00%
# Ensemble model saved successfully!
